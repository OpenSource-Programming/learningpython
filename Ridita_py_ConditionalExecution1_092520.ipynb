# %% [markdown]
# <a href="https://colab.research.google.com/github/OpenSource-Programming/learningpython/blob/ridita-py-092020/Ridita_py_ConditionalExecution1_092520.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hrs = input("Enter Hours:")
h = float(hrs)

rate = input("Enter Rate:")
float_rate = float(rate)

# Pay the hourly rate for the hours up to 40 and 1.5 times the hourly rate for all hours worked above 40 hours.
if h <= 40:
    print(h * float_rate)
elif h > 40:
    hours_above_forty = h-40
    print((40*float_rate) + (hours_above_forty*1.5*float_rate))
# Out:
# Enter Hours:35
# Enter Rate:2.75
# 96.25
